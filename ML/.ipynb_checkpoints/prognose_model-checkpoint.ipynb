# %%
# !pip install catboost
# !pip install XGBoost
from catboost import CatBoostRegressor
import xgboost as xgb
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error, r2_score, mean_absolute_error 
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: catboost in c:\users\olga\anaconda3\lib\site-packages (1.2.8)
# Requirement already satisfied: graphviz in c:\users\olga\anaconda3\lib\site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in c:\users\olga\anaconda3\lib\site-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in c:\users\olga\anaconda3\lib\site-packages (from catboost) (2.1.3)
# Requirement already satisfied: pandas>=0.24 in c:\users\olga\anaconda3\lib\site-packages (from catboost) (2.2.3)
# Requirement already satisfied: scipy in c:\users\olga\anaconda3\lib\site-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in c:\users\olga\anaconda3\lib\site-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in c:\users\olga\anaconda3\lib\site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\olga\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olga\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\olga\anaconda3\lib\site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\olga\anaconda3\lib\site-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\olga\anaconda3\lib\site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\olga\anaconda3\lib\site-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\olga\anaconda3\lib\site-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\olga\anaconda3\lib\site-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\olga\anaconda3\lib\site-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\olga\anaconda3\lib\site-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\olga\anaconda3\lib\site-packages (from plotly->catboost) (9.0.0)
# Requirement already satisfied: XGBoost in c:\users\olga\anaconda3\lib\site-packages (3.0.5)
# Requirement already satisfied: numpy in c:\users\olga\anaconda3\lib\site-packages (from XGBoost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\olga\anaconda3\lib\site-packages (from XGBoost) (1.15.3)

# %%
#загрузка датасетов для первой задачи
X1 = pd.read_excel('X1.xlsx')
X2 = pd.read_excel('X2.xlsx')
y1 = pd.read_excel('y1.xlsx')
y2 = pd.read_excel('y2.xlsx')

# %%
X1.head()
# Out:
#    Соотношение матрица-наполнитель  Плотность, кг/м3  модуль упругости, ГПа  \
# 0                         0.099781          0.625107               0.438928
# 1                         0.452019          0.625107               0.450658
# 2                         0.450704          0.538593               0.446546
# 3                         0.374299          0.279051               0.495066
# 4                         0.371161          0.250214               0.271382
#
#    Количество отвердителя, м.%  Содержание эпоксидных групп,%_2  \
# 0                     0.912803                         0.000000
# 1                     0.584256                         0.229622
# 2                     0.584256                         0.229622
# 3                     0.584256                         0.229622
# 4                     0.584256                         0.229622
#
#    Температура вспышки, С_2  Поверхностная плотность, г/м2  \
# 0                  0.711831                         0.0000
# 1                  0.416197                         0.0000
# 2                  0.416197                         0.0000
# 3                  0.416197                         0.0000
# 4                  0.416197                         0.2125
#
#    Прочность при растяжении, МПа  Потребление смолы, г/м2  Угол нашивки, град  \
# 0                       0.864468                 0.555556                   0
# 1                       0.864468                 0.555556                   0
# 2                       0.864468                 0.555556                   0
# 3                       0.864468                 0.555556                   0
# 4                       0.000000                 0.000000                   0
#
#    Шаг нашивки  Плотность нашивки
# 0     0.166667           0.000000
# 1     0.166667           0.434783
# 2     0.166667           0.565217
# 3     0.166667           1.000000
# 4     0.500000           0.000000

# %%
X2.head()
# Out:
#    Соотношение матрица-наполнитель  Плотность, кг/м3  модуль упругости, ГПа  \
# 0                         0.099781          0.625107               0.438928
# 1                         0.452019          0.625107               0.450658
# 2                         0.450704          0.538593               0.446546
# 3                         0.374299          0.279051               0.495066
# 4                         0.371161          0.250214               0.271382
#
#    Количество отвердителя, м.%  Содержание эпоксидных групп,%_2  \
# 0                     0.912803                         0.000000
# 1                     0.584256                         0.229622
# 2                     0.584256                         0.229622
# 3                     0.584256                         0.229622
# 4                     0.584256                         0.229622
#
#    Температура вспышки, С_2  Поверхностная плотность, г/м2  \
# 0                  0.711831                         0.0000
# 1                  0.416197                         0.0000
# 2                  0.416197                         0.0000
# 3                  0.416197                         0.0000
# 4                  0.416197                         0.2125
#
#    Модуль упругости при растяжении, ГПа  Потребление смолы, г/м2  \
# 0                              0.076092                 0.555556
# 1                              0.076092                 0.555556
# 2                              0.076092                 0.555556
# 3                              0.076092                 0.555556
# 4                              0.653534                 0.000000
#
#    Угол нашивки, град  Шаг нашивки  Плотность нашивки
# 0                   0     0.166667           0.000000
# 1                   0     0.166667           0.434783
# 2                   0     0.166667           0.565217
# 3                   0     0.166667           1.000000
# 4                   0     0.500000           0.000000

# %%
y1.head()
# Out:
#    Модуль упругости при растяжении, ГПа
# 0                              0.076092
# 1                              0.076092
# 2                              0.076092
# 3                              0.076092
# 4                              0.653534

# %%
y2.head()
# Out:
#    Прочность при растяжении, МПа
# 0                       0.864468
# 1                       0.864468
# 2                       0.864468
# 3                       0.864468
# 4                       0.000000

# %%
#Определние тестовой и обучающей выборок
X_train, X_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

#Определние тестовой и обучающей выборок
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.3, random_state=42)

# %%
#Метрики для определния качества моделей
def show_metric(y, y_pred):
    print('R^2: {:.4f}'.format(r2_score(y, y_pred)))
    print('MAE: {:.4f}'.format(mean_absolute_error(y, y_pred)))
    print('MSE: {:.4f}'.format(mean_squared_error(y, y_pred)))

#График для оценки предсказаний модели
def draw_pred_plt(y, y_pred, title):
    plt.figure(figsize=(10, 6))
    plt.scatter(y, y_pred, alpha=0.7)
    plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--', lw=2)
    plt.xlabel('Реальные значения')
    plt.ylabel('Предсказанные значения')
    plt.title('{}: Реальные vs Предсказанные значения'.format(title))
    plt.grid(True, alpha=0.3)
    plt.show()

# %% [markdown]
# **Модель случайного леса**

# %%
def rf_func(X_train, y_train, X_test, y_test, name):
    # Определяем модель
    rf_model = RandomForestRegressor(random_state=42)
    
    # Задаем сетку параметров для поиска
    param_grid = {
        'n_estimators': [100, 200, 300],
        'max_depth': [5, 10, 50],
        'min_samples_split': [2, 5, 10]
    }
    
    
    # Создаем объект GridSearchCV
    # cv=10 означает 10-блочную перекрёстную проверку
    grid_search = GridSearchCV(
        estimator=rf_model,
        param_grid=param_grid,
        scoring='neg_mean_absolute_error',
        cv=10,          # Количество блоков
        n_jobs=-1,      # Использовать все процессоры для параллельных вычислений
        verbose=1
    )
    
    # Запускаем подбор параметров на тренировочных данных
    grid_search.fit(X_train, y_train.values.ravel())
    
    # Лучшие найденные параметры
    print("Лучшие параметры:", grid_search.best_params_)
    
    # Лучшая модель
    best_model = grid_search.best_estimator_
    
    # Оцениваем на обучающих данных
    y_pred = best_model.predict(X_train)
    show_metric(y_train.values.ravel(),y_pred)
    draw_pred_plt(y_train.values.ravel(),y_pred, name + ' на обучающей выборке')

     # Оцениваем на тестовых данных
    y_pred = best_model.predict(X_test)
    show_metric(y_test.values.ravel(),y_pred)
    draw_pred_plt(y_test.values.ravel(),y_pred, name + ' на тестовой выборке')

# %%
rf_func(X_train, y1_train, X_test, y1_test, 'RF для модуля упругости')
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# Лучшие параметры: {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 200}
# R^2: 0.9840
# MAE: 0.0319
# MSE: 0.0018
# R^2: 0.8375
# MAE: 0.0562
# MSE: 0.0064

# %%
rf_func(X2_train, y2_train, X2_test, y2_test, 'RF для прочности')
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# Лучшие параметры: {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 300}
# R^2: 0.9461
# MAE: 0.0658
# MSE: 0.0067
# R^2: 0.5304
# MAE: 0.0983
# MSE: 0.0158

# %% [markdown]
# **Метод опорных векторов**

# %%
def svr_func(X_train, y_train, X_test, y_test, name):
    svr_model = SVR(kernel='rbf') 
    
    param_grid = {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto', 0.01, 0.1, 1],
        'epsilon': [0.01, 0.1, 0.2, 0.3]
    }
    
    grid_search = GridSearchCV(
        estimator=svr_model,
        param_grid=param_grid,
        scoring='neg_mean_squared_error',
        cv=10,
        n_jobs=-1,
        verbose=1  # Вывод процесса подбора
    )
    
    grid_search.fit(X_train, y_train.values.ravel())
    
    print("\nЛучшие гиперпараметры:", grid_search.best_params_)
    
    best_model = grid_search.best_estimator_
    
     # Оцениваем на обучающих данных
    y_pred = best_model.predict(X_train)
    show_metric(y_train.values.ravel(),y_pred)
    draw_pred_plt(y_train.values.ravel(),y_pred, name + ' на обучающей выборке')

     # Оцениваем на тестовых данных
    y_pred = best_model.predict(X_test)
    show_metric(y_test.values.ravel(),y_pred)
    draw_pred_plt(y_test.values.ravel(),y_pred, name + ' на тестовой выборке')

# %%
svr_func(X_train, y1_train, X_test, y1_test, 'SVR для модуля упругости')
# Out:
# Fitting 10 folds for each of 60 candidates, totalling 600 fits
#
# Лучшие гиперпараметры: {'C': 10, 'epsilon': 0.01, 'gamma': 'auto'}
# R^2: 0.9991
# MAE: 0.0098
# MSE: 0.0001
# R^2: 0.9466
# MAE: 0.0315
# MSE: 0.0021

# %%
svr_func(X2_train, y2_train, X2_test, y2_test, 'SVR для прочности')
# Out:
# Fitting 10 folds for each of 60 candidates, totalling 600 fits
#
# Лучшие гиперпараметры: {'C': 10, 'epsilon': 0.01, 'gamma': 0.1}
# R^2: 0.9993
# MAE: 0.0095
# MSE: 0.0001
# R^2: 0.8702
# MAE: 0.0459
# MSE: 0.0044

# %% [markdown]
# **XGBoost**

# %%
def xgb_func(X_train, y_train, X_test, y_test, name):
    xgb_model = xgb.XGBRegressor(
        random_state=42,
        n_jobs=-1,  # Использовать все ядра процессора
        early_stopping_rounds=10,  # Ранняя остановка для предотвращения переобучения
        eval_metric='rmse'  # Метрика для ранней остановки
    )
    
    param_grid = {
        'n_estimators': [5, 10, 50],  # Количество деревьев
        'max_depth': [3, 5, 7],  # Максимальная глубина деревьев
        'subsample': [0.8, 0.9, 1.0],  # Доля образцов для каждого дерева
        'colsample_bytree': [0.8, 0.9, 1.0],  # Доля признаков для каждого дерева
        'gamma': [0, 0.1, 0.2],  # Минимальное снижение потерь для разделения
        'reg_alpha': [0, 0.1],  # L1 регуляризация
        'reg_lambda': [1, 1.5]  # L2 регуляризация
    }
    
    grid_search = GridSearchCV(
        estimator=xgb_model,
        param_grid=param_grid,
        scoring='neg_mean_squared_error',
        cv=10,
        n_jobs=-1,
        verbose=1
    )

    
    grid_search.fit(X_train, y_train.values.ravel(), eval_set=[(X_test, y_test)])
    
    print("Лучшие гиперпараметры:", grid_search.best_params_)
    
    best_model = grid_search.best_estimator_
    
     # Оцениваем на обучающих данных
    y_pred = best_model.predict(X_train)
    show_metric(y_train.values.ravel(),y_pred)
    draw_pred_plt(y_train.values.ravel(),y_pred, name + ' на обучающей выборке')

     # Оцениваем на тестовых данных
    y_pred = best_model.predict(X_test)
    show_metric(y_test.values.ravel(),y_pred)
    draw_pred_plt(y_test.values.ravel(),y_pred, name + ' на тестовой выборке')

# %%
xgb_func(X_train, y1_train, X_test, y1_test, 'XGBoost для модуля упругости')
# Out:
# Fitting 10 folds for each of 972 candidates, totalling 9720 fits
# [0]	validation_0-rmse:0.24183
# [1]	validation_0-rmse:0.23333
# [2]	validation_0-rmse:0.20294
# [3]	validation_0-rmse:0.21311
# [4]	validation_0-rmse:0.22684
# [5]	validation_0-rmse:0.23964
# [6]	validation_0-rmse:0.23492
# [7]	validation_0-rmse:0.23211
# [8]	validation_0-rmse:0.24069
# [9]	validation_0-rmse:0.24767
# [10]	validation_0-rmse:0.25051
# [11]	validation_0-rmse:0.25272
# [12]	validation_0-rmse:0.25442
# Лучшие гиперпараметры: {'colsample_bytree': 1.0, 'gamma': 0, 'max_depth': 5, 'n_estimators': 50, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1.0}
# R^2: 0.7530
# MAE: 0.1365
# MSE: 0.0274
# R^2: -0.0478
# MAE: 0.1903
# MSE: 0.0412

# %%
xgb_func(X2_train, y2_train, X2_test, y2_test, 'XGBoost для прочности')
# Out:
# Fitting 10 folds for each of 972 candidates, totalling 9720 fits
# [0]	validation_0-rmse:0.22641
# [1]	validation_0-rmse:0.20110
# [2]	validation_0-rmse:0.16603
# [3]	validation_0-rmse:0.13247
# [4]	validation_0-rmse:0.12304
# [5]	validation_0-rmse:0.11361
# [6]	validation_0-rmse:0.11404
# [7]	validation_0-rmse:0.11942
# [8]	validation_0-rmse:0.12135
# [9]	validation_0-rmse:0.12445
# [10]	validation_0-rmse:0.12181
# [11]	validation_0-rmse:0.11795
# [12]	validation_0-rmse:0.11795
# [13]	validation_0-rmse:0.11924
# [14]	validation_0-rmse:0.12048
# Лучшие гиперпараметры: {'colsample_bytree': 1.0, 'gamma': 0.1, 'max_depth': 3, 'n_estimators': 50, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.9}
# R^2: 0.8814
# MAE: 0.1018
# MSE: 0.0149
# R^2: 0.6164
# MAE: 0.0999
# MSE: 0.0129

# %% [markdown]
# **CatBoost**

# %%
def catboost_func(X_train, y_train, X_test, y_test, name):
    cb_model = CatBoostRegressor(
        random_state=42,
        eval_metric='RMSE'  # Метрика для ранней остановки
    )
    
    param_grid = {
        'n_estimators': [5, 10, 50],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.03, 0.1],
        'l2_leaf_reg': [1, 3, 5, 7, 9]
     }
    
    grid_search = GridSearchCV(
        estimator=cb_model,
        param_grid=param_grid,
        scoring='neg_mean_squared_error',
        cv=10,
        n_jobs=-1,
        verbose=1
    )
    grid_search.fit(X_train, y_train.values.ravel(), eval_set=[(X_test, y_test)])

    print("Лучшие гиперпараметры:", grid_search.best_params_)
    
    best_model = grid_search.best_estimator_
    
     # Оцениваем на обучающих данных
    y_pred = best_model.predict(X_train)
    show_metric(y_train.values.ravel(),y_pred)
    draw_pred_plt(y_train.values.ravel(),y_pred, name + ' на обучающей выборке')

     # Оцениваем на тестовых данных
    y_pred = best_model.predict(X_test)
    show_metric(y_test.values.ravel(),y_pred)
    draw_pred_plt(y_test.values.ravel(),y_pred, name + ' на тестовой выборке')

# %%
catboost_func(X_train, y1_train, X_test, y1_test, 'CatBoost для модуля упругости')
# Out:
# Fitting 10 folds for each of 90 candidates, totalling 900 fits
# 0:	learn: 0.3130187	test: 0.2558920	best: 0.2558920 (0)	total: 118ms	remaining: 5.76s
# 1:	learn: 0.2929807	test: 0.2460852	best: 0.2460852 (1)	total: 121ms	remaining: 2.89s
# 2:	learn: 0.2796523	test: 0.2442958	best: 0.2442958 (2)	total: 122ms	remaining: 1.91s
# 3:	learn: 0.2617504	test: 0.2355271	best: 0.2355271 (3)	total: 122ms	remaining: 1.41s
# 4:	learn: 0.2458910	test: 0.2235733	best: 0.2235733 (4)	total: 123ms	remaining: 1.1s
# 34:	learn: 0.0405564	test: 0.0497275	best: 0.0497275 (34)	total: 11.3ms	remaining: 4.85ms
# 35:	learn: 0.0381013	test: 0.0488882	best: 0.0488882 (35)	total: 12.3ms	remaining: 4.78ms
# 36:	learn: 0.0358652	test: 0.0481940	best: 0.0481940 (36)	total: 12.6ms	remaining: 4.43ms
# 37:	learn: 0.0339074	test: 0.0471164	best: 0.0471164 (37)	total: 12.9ms	remaining: 4.07ms
# 38:	learn: 0.0319109	test: 0.0474159	best: 0.0471164 (37)	total: 13.2ms	remaining: 3.72ms
# 39:	learn: 0.0301633	test: 0.0467884	best: 0.0467884 (39)	total: 13.4ms	remaining: 3.36ms
# 40:	learn: 0.0284871	test: 0.0457108	best: 0.0457108 (40)	total: 13.7ms	remaining: 3.01ms
# 41:	learn: 0.0267848	test: 0.0451491	best: 0.0451491 (41)	total: 14.1ms	remaining: 2.68ms
# 42:	learn: 0.0256342	test: 0.0451129	best: 0.0451129 (42)	total: 14.3ms	remaining: 2.34ms
# 43:	learn: 0.0242541	test: 0.0452417	best: 0.0451129 (42)	total: 14.6ms	remaining: 2ms
# 44:	learn: 0.0228456	test: 0.0447994	best: 0.0447994 (44)	total: 14.9ms	remaining: 1.65ms
# 45:	learn: 0.0215303	test: 0.0440841	best: 0.0440841 (45)	total: 15.1ms	remaining: 1.31ms
# 46:	learn: 0.0203720	test: 0.0434801	best: 0.0434801 (46)	total: 15.3ms	remaining: 979us
# 47:	learn: 0.0192075	test: 0.0429102	best: 0.0429102 (47)	total: 15.6ms	remaining: 649us
# 48:	learn: 0.0182921	test: 0.0429015	best: 0.0429015 (48)	total: 15.8ms	remaining: 323us
# 49:	learn: 0.0173359	test: 0.0424197	best: 0.0424197 (49)	total: 16.1ms	remaining: 0us
#
# bestTest = 0.04241968882
# bestIteration = 49
#
# Лучшие гиперпараметры: {'l2_leaf_reg': 1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# R^2: 0.9976
# MAE: 0.0140
# MSE: 0.0003
# R^2: 0.9465
# MAE: 0.0310
# MSE: 0.0018

# %% [markdown]
# **KNN Регрессия**

# %%
def knn_func(X_train, y_train, X_test, y_test, name):
    
    knn =  KNeighborsRegressor()
    
    param_grid = {
        'n_neighbors': [1, 2],  # Количество соседей
        'weights': ['uniform', 'distance'],  # Весовая функция
    }
    
    grid_search = GridSearchCV(
        estimator=knn,
        param_grid=param_grid,
        scoring='neg_mean_squared_error',
        cv=10,
        n_jobs=-1
    )
    
    grid_search.fit(X_train, y_train.values.ravel())
    
    print("Лучшие гиперпараметры:", grid_search.best_params_)
    
    best_model = grid_search.best_estimator_
    
     # Оцениваем на обучающих данных
    y_pred = best_model.predict(X_train)
    show_metric(y_train.values.ravel(),y_pred)
    draw_pred_plt(y_train.values.ravel(),y_pred, name + ' на обучающей выборке')

     # Оцениваем на тестовых данных
    y_pred = best_model.predict(X_test)
    show_metric(y_test.values.ravel(),y_pred)
    draw_pred_plt(y_test.values.ravel(),y_pred, name + ' на тестовой выборке')

# %%
knn_func(X_train, y1_train, X_test, y1_test, 'KNN для модуля упругости')
# Out:
# Лучшие гиперпараметры: {'n_neighbors': 2, 'weights': 'distance'}
# R^2: 1.0000
# MAE: 0.0000
# MSE: 0.0000
# R^2: 0.0230
# MAE: 0.1462
# MSE: 0.0384

# %%
knn_func(X_train, y2_train, X_test, y2_test, 'KNN для прочности')
# Out:
# Лучшие гиперпараметры: {'n_neighbors': 2, 'weights': 'distance'}
# R^2: 1.0000
# MAE: 0.0000
# MSE: 0.0000
# R^2: -0.1284
# MAE: 0.1514
# MSE: 0.0380

# %% [markdown]
# **Многослойный перцептрон**

# %%
#Определние тестовой и обучающей выборок
X_for_MLP = pd.read_excel('X_for_MLP.xlsx')
y3 = pd.read_excel('y3.xlsx')
X3_train, X3_test, y3_train, y3_test = train_test_split(X_for_MLP, y3, test_size=0.3, random_state=42)

# %%
X_for_MLP
# Out:
#     Плотность, кг/м3  модуль упругости, ГПа  Количество отвердителя, м.%  \
# 0           0.625107               0.438928                     0.912803
# 1           0.625107               0.450658                     0.584256
# 2           0.538593               0.446546                     0.584256
# 3           0.279051               0.495066                     0.584256
# 4           0.250214               0.271382                     0.584256
# 5           0.336727               0.562500                     0.912803
# 6           0.826972               1.000000                     0.912803
# 7           1.000000               0.598684                     0.912803
# 8           0.394403               0.511513                     0.912803
# 9           0.480917               0.298520                     0.912803
# 10          0.279051               0.489309                     0.912803
# 11          0.625107               0.079770                     0.912803
# 12          0.192538               0.088816                     0.912803
# 13          0.394403               0.247533                     0.912803
# 14          0.538593               0.000000                     0.584256
# 15          0.307889               0.206414                     0.584256
# 16          0.192538               0.342928                     0.584256
# 17          0.647115               0.413298                     0.387919
# 18          0.227348               0.358596                     0.291042
# 19          0.285729               0.804352                     1.000000
# 20          0.192451               0.656472                     0.534026
# 21          0.000000               0.454667                     0.000000
# 22          0.785145               0.597295                     0.559430
#
#     Содержание эпоксидных групп,%_2  Температура вспышки, С_2  \
# 0                          0.000000                  0.711831
# 1                          0.229622                  0.416197
# 2                          0.229622                  0.416197
# 3                          0.229622                  0.416197
# 4                          0.229622                  0.416197
# 5                          0.000000                  0.711831
# 6                          0.000000                  0.711831
# 7                          0.000000                  0.711831
# 8                          0.000000                  0.711831
# 9                          0.000000                  0.711831
# 10                         0.000000                  0.711831
# 11                         0.000000                  0.711831
# 12                         0.000000                  0.711831
# 13                         0.000000                  0.711831
# 14                         0.229622                  0.416197
# 15                         0.229622                  0.416197
# 16                         0.229622                  0.416197
# 17                         0.427813                  0.948329
# 18                         0.392372                  0.000000
# 19                         0.454299                  1.000000
# 20                         1.000000                  0.597467
# 21                         0.490093                  0.309831
# 22                         0.504683                  0.140856
#
#     Поверхностная плотность, г/м2  Прочность при растяжении, МПа  \
# 0                        0.000000                       0.864468
# 1                        0.000000                       0.864468
# 2                        0.000000                       0.864468
# 3                        0.000000                       0.864468
# 4                        0.212500                       0.000000
# 5                        0.212500                       0.000000
# 6                        1.000000                       0.144078
# 7                        1.000000                       0.144078
# 8                        0.325000                       0.472256
# 9                        0.325000                       0.472256
# 10                       0.325000                       0.472256
# 11                       0.000000                       0.864468
# 12                       0.000000                       0.864468
# 13                       0.212500                       0.000000
# 14                       1.000000                       0.144078
# 15                       0.325000                       0.472256
# 16                       0.325000                       0.472256
# 17                       0.422002                       0.593621
# 18                       0.743241                       0.352247
# 19                       0.209236                       0.362912
# 20                       0.247943                       0.926815
# 21                       0.456329                       1.000000
# 22                       0.085288                       0.677332
#
#     Потребление смолы, г/м2  Угол нашивки, град  Шаг нашивки  \
# 0                  0.555556                   0     0.166667
# 1                  0.555556                   0     0.166667
# 2                  0.555556                   0     0.166667
# 3                  0.555556                   0     0.166667
# 4                  0.000000                   0     0.500000
# 5                  0.000000                   0     0.500000
# 6                  1.000000                   0     0.500000
# 7                  1.000000                   0     0.500000
# 8                  0.555556                   0     0.833333
# 9                  0.555556                   0     0.833333
# 10                 0.555556                   0     0.833333
# 11                 0.555556                   0     1.000000
# 12                 0.555556                   0     1.000000
# 13                 0.000000                   0     1.000000
# 14                 1.000000                   1     0.000000
# 15                 0.555556                   1     0.000000
# 16                 0.555556                   1     0.000000
# 17                 0.323325                   1     0.166667
# 18                 0.037869                   1     0.500000
# 19                 0.447668                   1     0.833333
# 20                 0.401062                   1     0.833333
# 21                 0.738170                   1     0.833333
# 22                 0.377008                   1     1.000000
#
#     Плотность нашивки
# 0            0.000000
# 1            0.434783
# 2            0.565217
# 3            1.000000
# 4            0.000000
# 5            0.434783
# 6            0.565217
# 7            1.000000
# 8            0.434783
# 9            0.565217
# 10           1.000000
# 11           0.000000
# 12           0.434783
# 13           0.565217
# 14           0.000000
# 15           0.434783
# 16           0.565217
# 17           0.434783
# 18           0.000000
# 19           0.434783
# 20           0.565217
# 21           1.000000
# 22           0.565217

# %%
y3
# Out:
#     Соотношение матрица-наполнитель
# 0                          0.099781
# 1                          0.452019
# 2                          0.450704
# 3                          0.374299
# 4                          0.371161
# 5                          0.754744
# 6                          0.745235
# 7                          0.509177
# 8                          0.000000
# 9                          0.509177
# 10                         0.936648
# 11                         0.514997
# 12                         0.754744
# 13                         1.000000
# 14                         0.492871
# 15                         0.000000
# 16                         0.936648
# 17                         0.172730
# 18                         0.428216
# 19                         0.534100
# 20                         0.507817
# 21                         0.635532
# 22                         0.325966

# %%
# Создание модели
mlp = Pipeline([
    ('mlp', MLPRegressor(
        hidden_layer_sizes=(100, 50, 50, 50),
        activation='identity',
        solver='sgd',
        max_iter=100000,
        random_state=42,
        learning_rate= 'adaptive',
        warm_start=True
    ))
])

# Обучение и предсказание
mlp.fit(X3_train, y3_train.values.ravel())

# Оцениваем на обучающих данных
y_pred = mlp.predict(X3_train)
show_metric(y3_train.values.ravel(),y_pred)
draw_pred_plt(y3_train.values.ravel(),y_pred, 'Многослойный перцептрон на обучающей выборке')

# Оцениваем на тестовых данных
y_pred = mlp.predict(X3_test)
show_metric(y3_test.values.ravel(),y_pred)
draw_pred_plt(y3_test.values.ravel(),y_pred, 'Многослойный перцептрон на тестовой выборке')
# Out:
# R^2: -0.4608
# MAE: 0.2000
# MSE: 0.0641
# R^2: -0.3802
# MAE: 0.2743
# MSE: 0.1002
